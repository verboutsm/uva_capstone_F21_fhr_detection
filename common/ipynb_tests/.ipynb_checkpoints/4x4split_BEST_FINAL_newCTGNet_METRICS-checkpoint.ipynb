# %% [markdown]
# # UVA SDS CAPSTONE
#
# ## EXTERNAL FETAL MONITORING; FHR/UC CLASSIFY PATTERNS
#
# ### Landon Blakey, Stephanie Verbout, Shashank Sharma, Hayley Kisiel
#
# ### 28 April 2022

# %% [markdown]
# #### This notebook does 4 times repeated, 4-fold cross-validation on the data set with Adapted CTGNet neural network classification.

# %%
import os
import glob
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.datasets import load_files 
from keras.utils import np_utils
from tensorflow import keras
from keras.preprocessing import image
from tensorflow.keras import layers
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold


#!pip install tqdm
from tqdm import tqdm # progress bar

# %%
# Resets notebook state
tf.keras.backend.clear_session()

print("Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print(
    "GPU is",
    "available" if tf.config.list_physical_devices("GPU") else "NOT AVAILABLE")
# Out:
# Version:  2.8.0
# Eager mode:  True
# GPU is available

# %%
# set seeds for reproducibility
np.random.seed(142) # note that you must use the same seed to ensure consistentcy in your training/validation/testing
tf.random.set_seed(142)

# %%
# set up image directory and sizes
data_dir = "../common/images/"

# %%
# set batch size
batch_size = 32;
# IMPORTANT: Depends on what pre-trained model you choose, you will need to change these dimensions accordingly
img_height = 299; 
img_width = 299;
class_names = ['ACC','DEC_EARLY','DEC_LATE','DEC_VAR','NONE']

# %%
# build the datasets
# Training Dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='int',
    class_names=class_names,
    validation_split = 0.11,
    subset = "training",
    seed = 142,
    image_size= (img_height, img_width),
    batch_size = batch_size
)

# Validation Dataset
holdout_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='int',
    class_names=class_names,
    validation_split = 0.11,
    subset = "validation",
    seed = 142,
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 2398 files belonging to 5 classes.
# Using 2135 files for training.
# Found 2398 files belonging to 5 classes.
# Using 263 files for validation.
# 2022-05-05 09:49:46.926220: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-05 09:49:48.902149: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38397 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:b7:00.0, compute capability: 8.0

# %%
# verify correct class names
train_ds.class_names
# Out:
# ['ACC', 'DEC_EARLY', 'DEC_LATE', 'DEC_VAR', 'NONE']

# %%
# display some example images
class_names = ['ACC','DEC_EARLY','DEC_LATE','DEC_VAR','NONE']

NUM_CLASSES = len(class_names)

# Rows and columns are set to fit one training batch (32)
n_rows = 2
n_cols = 4
plt.figure(figsize=(n_cols * 3, n_rows * 3))
for images, labels in train_ds.take(1):
    for i in range (n_rows*n_cols):
        plt.subplot(n_rows, n_cols, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis('off')
        plt.title(class_names[labels[i]], fontsize=12)
plt.subplots_adjust(wspace=.2, hspace=.2)

# %%
# Resets notebook state
tf.keras.backend.clear_session()

# %% [markdown]
# # ADAPTED CTGNet

# %%
# define function to build the Adapted CTGNet

def build_AdaptedCTGNet_model(trainable_layers=15, verbose=False):

    # for Adapted CTGNet, all layers are trainable
    model = keras.models.Sequential([
            keras.layers.InputLayer(input_shape=[299,299,3],   
                                    dtype='float32',
                                    input_tensor=None,
                                    sparse=False,
                                    name='input_1',
                                    ragged=None,
                                    type_spec=None),
            keras.layers.Conv2D(filters=4,                        # batch_input_shape = [1, 2, 1800]
                                kernel_size=(1,30),
                                strides=(1, 1),
                                padding='same',
                                data_format='channels_last',
                                dilation_rate=(1, 1),
                                groups=1,
                                activation='linear',
                                use_bias=False,
                                kernel_initializer='he_normal',
                                bias_initializer='zeros',
                                kernel_regularizer=None,
                                bias_regularizer=None,
                                activity_regularizer=None,
                                kernel_constraint=None,
                                bias_constraint=None,
                                trainable=True,
                                name='conv2d'),
            keras.layers.BatchNormalization(axis=3,
                                            momentum=0.99,
                                            epsilon=0.001,
                                            center=True,scale=True,
                                            trainable=True,
                                            name='batch_normalization'),
            keras.layers.DepthwiseConv2D(kernel_size = (2, 1),
                                         strides=(1, 1),
                                         padding='valid',
                                         depth_multiplier=2,
                                         data_format='channels_last',
                                         dilation_rate=(1, 1),
                                         activation='linear',
                                         use_bias=False,
                                         depthwise_initializer='he_normal',
                                         bias_initializer='zeros',
                                         depthwise_regularizer=None,
                                         bias_regularizer=None,
                                         activity_regularizer=None,
                                         depthwise_constraint="MaxNorm",
                                         bias_constraint=None,
                                         trainable=True,
                                         name='depthwise_conv2d'),
            keras.layers.BatchNormalization(axis=3,
                                            momentum=0.99,
                                            epsilon=0.001,
                                            center=True,
                                            scale=True,
                                            trainable=True,
                                            name='batch_normalization_1'),
            keras.layers.Activation('elu', 
                                    trainable=True, 
                                    name='activation'),
            keras.layers.MaxPooling2D(pool_size=(1,4), 
                                      strides=(1,4), 
                                      padding='valid', 
                                      data_format='channels_last',
                                      trainable=True,
                                      name='max_pooling2d'),
            keras.layers.Dropout(0.50, 
                                 trainable=True, 
                                 name='dropout'),
            keras.layers.SeparableConv2D(filters=8,
                                         kernel_size=(1,7),
                                         strides=(1, 1),
                                         padding='same',
                                         data_format='channels_last',
                                         dilation_rate=(1, 1),
                                         depth_multiplier=1,
                                         activation='linear',
                                         use_bias=False,
                                         depthwise_initializer='he_normal',
                                         pointwise_initializer='he_normal',
                                         bias_initializer='zeros',
                                         trainable=True,
                                         name='separable_conv2d'),
            keras.layers.BatchNormalization(axis=3,
                                            momentum=0.99,
                                            epsilon=0.001,
                                            center=True,
                                            scale=True,
                                            trainable=True,
                                            name='batch_normalization_2'),
            keras.layers.Activation('elu', 
                                    trainable=True, 
                                    name='activation_1'),
            keras.layers.MaxPooling2D(pool_size=(1,4), 
                                      strides=(1,4), 
                                      padding='valid', 
                                      data_format='channels_last',
                                      trainable=True,
                                      name='max_pooling2d_1'),
            keras.layers.Dropout(0.50, 
                                 trainable=True, 
                                 name='dropout_1'),
            keras.layers.Flatten(data_format='channels_last', 
                                 trainable=True, 
                                 name='flatten'),
            keras.layers.Dense(units=NUM_CLASSES*150,
                               activation='linear',
                               use_bias=True,
                               kernel_initializer='he_normal',
                               bias_initializer='zeros',
                               kernel_regularizer=tf.keras.regularizers.l2(0.01),
                               bias_regularizer=None,
                               activity_regularizer=None,
                               kernel_constraint='MaxNorm',
                               trainable=True,
                               name='dense1'),
            keras.layers.Dense(units=NUM_CLASSES*75,
                               activation='linear',
                               use_bias=True,
                               kernel_initializer='he_normal',
                               bias_initializer='zeros',
                               kernel_regularizer=tf.keras.regularizers.l2(0.01),
                               bias_regularizer=None,
                               activity_regularizer=None,
                               kernel_constraint='MaxNorm',
                               trainable=True,
                               name='dense2'),
            keras.layers.Dense(units=NUM_CLASSES,
                               activation='softmax',
                               trainable=True,
                               name='softmax_output')   # we need
            ])

    optimizer = keras.optimizers.Adam(learning_rate=1e-4)
     
    # use sparse_categorical_crossentropy as labels are not one-hot encoded
    model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=['sparse_categorical_accuracy'])

    if verbose:
        print(model.summary())
    
    return model

# %%
flat_train_ds = train_ds.unbatch()
train_list = list(flat_train_ds.as_numpy_iterator())

# %%
# concatenate
trainImages = []
trainLabels =  []
for x, y in train_list:
    trainImages.append(x)
    trainLabels.append(y)
    
train_images = np.array((trainImages))
train_labels = np.array((trainLabels))

# %%
print('train_images shape:', train_images.shape, 'train_labels shape:', train_labels.shape)
# Out:
# train_images shape: (2135, 299, 299, 3) train_labels shape: (2135,)

# %%
train_label_list = train_labels.tolist()

def countX(lst):
    d = {
        '0': 0,
        '1': 0,
        '2': 0,
        '3': 0,
        '4': 0
    }
    for ele in lst:
        d[str(ele)] += 1
    print( f"\n\
          ACC: {d['0']} \n\
          DEC_EARLY: {d['1']} \n\
          DEC_LATE: {d['2']} \n\
          DEC_VAR: {d['3']} \n\
          NONE: {d['4']}"
         )
countX(train_label_list)
# Out:
#           ACC: 471
#           DEC_EARLY: 752
#           DEC_LATE: 148
#           DEC_VAR: 105
#           NONE: 659

# %%
holdout_label_list =  []
for _, y in holdout_ds.unbatch():
    holdout_label_list.append(y.numpy())
    
countX(holdout_label_list)
# Out:
#           ACC: 52
#           DEC_EARLY: 97
#           DEC_LATE: 22
#           DEC_VAR: 11
#           NONE: 81

# %%
# Define per-fold score containers and history list
acc_per_fold = []
loss_per_fold = []
histories = []
models = []
splits = []
# Define the K-fold Cross Validator
#kfold = KFold(n_splits=5, shuffle=True)
rkf = RepeatedKFold(n_splits=4, n_repeats=4, random_state=142)

# %%
# fit the model to image data and train
# K-fold Cross Validation model evaluation
fold_no = 1
for train, test in rkf.split(train_images,train_labels):
    
    # build the model with function above
    model = build_AdaptedCTGNet_model()
    
    
    history = model.fit(train_images[train],
                        train_labels[train],
                        validation_data = (train_images[test], train_labels[test]),
                        epochs=40,
                        batch_size = batch_size,
                        callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3),
                                    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                                         factor=0.1,
                                                                         patience=3,
                                                                         verbose=1,
                                                                         mode='auto',
                                                                         min_delta=0.0001,
                                                                         cooldown=0,
                                                                         min_lr=1e-7)],
                        verbose=1
                        )


    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')


    # Generate generalization metrics
    scores = model.evaluate(holdout_ds)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])
    histories.append(history)
    models.append(model)
    splits.append((train, test))
    # save model
    model.save(f'new_split_CTG_model_final_crossValidation{fold_no}')
    
    # Increase fold number
    fold_no = fold_no + 1
# Out:
# Epoch 1/40
# 2022-05-05 10:32:07.641225: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# 2022-05-05 10:32:12.477503: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 51/51 [==============================] - 16s 153ms/step - loss: 37.7923 - sparse_categorical_accuracy: 0.3404 - val_loss: 58.3013 - val_sparse_categorical_accuracy: 0.3240 - lr: 1.0000e-04
# Epoch 2/40
# 51/51 [==============================] - 7s 144ms/step - loss: 31.4522 - sparse_categorical_accuracy: 0.3941 - val_loss: 36.9709 - val_sparse_categorical_accuracy: 0.3258 - lr: 1.0000e-04
# Epoch 3/40
# 51/51 [==============================] - 7s 144ms/step - loss: 28.5870 - sparse_categorical_accuracy: 0.4160 - val_loss: 27.6938 - val_sparse_categorical_accuracy: 0.2247 - lr: 1.0000e-04
# Epoch 4/40
# 51/51 [==============================] - 7s
40
# 51/51 [==============================] - 7s 143ms/step - loss: 12.7968 - sparse_categorical_accuracy: 0.6827 - val_loss: 13.3876 - val_sparse_categorical_accuracy: 0.4176 - lr: 1.0000e-04
# Epoch 32/40
# 51/51 [==============================] - 7s 144ms/step - loss: 12.4358 - sparse_categorical_accuracy: 0.7264 - val_loss: 13.1524 - val_sparse_categorical_accuracy: 0.3708 - lr: 1.0000e-04
# Epoch 33/40
# 51/51 [==============================] - 7s 143ms/step - loss: 12.0829 - sparse_categorical_accuracy: 0.7320 - val_loss: 12.9483 - val_sparse_categorical_accuracy: 0.3876 - lr: 1.0000e-04
# Epoch 34/40
# 51/51 [==============================] - 7s 143ms/step - loss: 11.7703 - sparse_categorical_accuracy: 0.7277 - val_loss: 12.5295 - val_sparse_categorical_accuracy: 0.3764 - lr: 1.0000e-04
# Epoch 35/40
# 51/51 [==============================] - 7s 142ms/step - loss: 11.4891 - sparse_categorical_accuracy: 0.7146 - val_loss: 12.4224 - val_sparse_categorical_accuracy: 0.4270 - lr: 1.0000e-04
# Epoch 36/40
# 51/51 [==============================] - 7s 144ms/step - loss: 11.2330 - sparse_categorical_accuracy: 0.7270 - val_loss: 11.9892 - val_sparse_categorical_accuracy: 0.4232 - lr: 1.0000e-04
# Epoch 37/40
# 51/51 [==============================] - 7s 143ms/step - loss: 11.0652 - sparse_categorical_accuracy: 0.6833 - val_loss: 11.8596 - val_sparse_categorical_accuracy: 0.4082 - lr: 1.0000e-04
# Epoch 38/40
# 51/51 [==============================] - 7s 144ms/step - loss: 10.5931 - sparse_categorical_accuracy: 0.7639 - val_loss: 11.4764 - val_sparse_categorical_accuracy: 0.3708 - lr: 1.0000e-04
# Epoch 39/40
# 51/51 [==============================] - 7s 144ms/step - loss: 10.4078 - sparse_categorical_accuracy: 0.7233 - val_loss: 11.3160 - val_sparse_categorical_accuracy: 0.4232 - lr: 1.0000e-04
# Epoch 40/40
# 51/51 [==============================] - 7s 143ms/step - loss: 10.1725 - sparse_categorical_accuracy: 0.7477 - val_loss: 11.1002 - val_sparse_categorical_accuracy: 0.3670 - lr: 1.0000e-04
# ------------------------------------------------------------------------
# Training for fold 14 ...
# 9/9 [==============================] - 0s 9ms/step - loss: 11.1147 - sparse_categorical_accuracy: 0.3916
# Score for fold 14: loss of 11.114651679992676; sparse_categorical_accuracy of 39.16349709033966%
# INFO:tensorflow:Assets written to: new_split_CTG_model_final_crossValidation14/assets
# Epoch 1/40
# 51/51 [==============================] - 9s 154ms/step - loss: 38.7372 - sparse_categorical_accuracy: 0.3398 - val_loss: 39.5384 - val_sparse_categorical_accuracy: 0.2491 - lr: 1.0000e-04
# Epoch 2/40
# 51/51 [==============================] - 7s 143ms/step - loss: 27.6586 - sparse_categorical_accuracy: 0.3879 - val_loss: 43.0012 - val_sparse_categorical_accuracy: 0.2397 - lr: 1.0000e-04
# Epoch 3/40
# 51/51 [==============================] - 7s 144ms/step - loss: 27.2668 - sparse_categorical_accuracy: 0.4335 - val_loss: 25.2358 - val_sparse_categorical_accuracy: 0.2753 - lr: 1.0000e-04
# Epoch 4/40
# 51/51 [==============================] - 7s 142ms/step - loss: 25.3831 - sparse_categorical_accuracy: 0.4772 - val_loss: 26.3133 - val_sparse_categorical_accuracy: 0.2397 - lr: 1.0000e-04
# Epoch 5/40
# Epoch 21/40
# 51/51 [==============================] - 7s 145ms/step - loss: 15.4302 - sparse_categorical_accuracy: 0.6396 - val_loss: 16.0961 - val_sparse_categorical_accuracy: 0.3745 - lr: 1.0000e-04
# Epoch 22/40
# 51/51 [==============================] - 7s 145ms/step - loss: 14.9874 - sparse_categorical_accuracy: 0.6883 - val_loss: 15.7328 - val_sparse_categorical_accuracy: 0.3895 - lr: 1.0000e-04
# Epoch 23/40
# 51/51 [==============================] - 7s 145ms/step - loss: 14.5784 - sparse_categorical_accuracy: 0.7071 - val_loss: 15.4463 - val_sparse_categorical_accuracy: 0.3839 - lr: 1.0000e-04
# Epoch 24/40
# 51/51 [==============================] - 7s 146ms/step - loss: 14.2353 - sparse_categorical_accuracy: 0.7039 - val_loss: 15.0840 - val_sparse_categorical_accuracy: 0.3914 - lr: 1.0000e-04
# Epoch 25/40
# 51/51 [==============================] - 7s 144ms/step - loss: 13.8821 - sparse_categorical_accuracy: 0.7277 - val_loss: 15.0051 - val_sparse_categorical_accuracy: 0.3689 - lr: 1.0000e-04
# Epoch 26/40
# 51/51 [==============================] - 7s 146ms/step - loss: 14.0371 - sparse_categorical_accuracy: 0.6508 - val_loss: 14.6687 - val_sparse_categorical_accuracy: 0.4026 - lr: 1.0000e-04
# Epoch 27/40
# 51/51 [==============================] - 7s 144ms/step - loss: 13.5929 - sparse_categorical_accuracy: 0.6596 - val_loss: 14.0690 - val_sparse_categorical_accuracy: 0.4026 - lr: 1.0000e-04
# Epoch 28/40
# 51/51 [==============================] - 7s 145ms/step - loss: 13.1698 - sparse_categorical_accuracy: 0.6683 - val_loss: 13.6245 - val_sparse_categorical_accuracy: 0.3970 - lr: 1.0000e-04
# Epoch 29/40
# 51/51 [==============================] - 7s 144ms/step - loss: 12.9386 - sparse_categorical_accuracy: 0.6665 - val_loss: 13.5265 - val_sparse_categorical_accuracy: 0.3876 - lr: 1.0000e-04
# Epoch 30/40
# 51/51 [==============================] - 7s 145ms/step - loss: 12.4305 - sparse_categorical_accuracy: 0.7333 - val_loss: 13.1758 - val_sparse_categorical_accuracy: 0.4288 - lr: 1.0000e-04
# Epoch 31/40
# 21/51 [===========>..................] - ETA: 4s - loss: 12.3525 - sparse_categorical_accuracy: 0.6905
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')

for i in range(0, len(acc_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')

print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 11.962093353271484 - Accuracy: 30.41824996471405%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 10.016727447509766 - Accuracy: 46.76806032657623%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 10.169238090515137 - Accuracy: 43.72623562812805%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 9.868380546569824 - Accuracy: 48.28897416591644%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 10.250838279724121 - Accuracy: 43.34600865840912%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 10.533044815063477 - Accuracy: 30.798479914665222%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 11.135322570800781 - Accuracy: 49.04943108558655%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 10.950653076171875 - Accuracy: 44.86691951751709%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 10.274023056030273 - Accuracy: 49.04943108558655%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 11.080805778503418 - Accuracy: 33.46007466316223%
# ------------------------------------------------------------------------
# > Fold 11 - Loss: 11.567154884338379 - Accuracy: 47.148290276527405%
# ------------------------------------------------------------------------
# > Fold 12 - Loss: 10.505030632019043 - Accuracy: 42.96577870845795%
# ------------------------------------------------------------------------
# > Fold 13 - Loss: 29.04067039489746 - Accuracy: 30.798479914665222%
# ------------------------------------------------------------------------
# > Fold 14 - Loss: 11.114651679992676 - Accuracy: 39.16349709033966%
# ------------------------------------------------------------------------
# > Fold 15 - Loss: 10.966360092163086 - Accuracy: 43.34600865840912%
# ------------------------------------------------------------------------
# > Fold 16 - Loss: 11.15164566040039 - Accuracy: 36.12167239189148%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 41.20722450315952 (+- 6.588316974755399)
# > Loss: 11.9116650223732
# ------------------------------------------------------------------------

# %%
# save model
#model.save('CTG_model_final_crossValidation')

# %%
# define function to plot the accuracies of train and validation set
def plot_hist(hist):
    
    plt.rcParams["figure.figsize"] = (12,8)
    plt.plot(hist.history["sparse_categorical_accuracy"])
    plt.plot(hist.history["val_sparse_categorical_accuracy"])
    plt.title("Adapted CTGNet Model Accuracy")
    plt.ylabel("Accuracy")
    plt.xlabel("Epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.ylim(0.0,1.0)
    plt.show()

# %%
# plot the accuracies and epochs    
plot_hist(histories[0])

# %%
plot_hist(histories[1])

# %%
plot_hist(histories[2])

# %%
plot_hist(histories[3])

# %%
# plot the accuracies and epochs
plot_hist(histories[4])

# %%
plot_hist(histories[5])

# %%
plot_hist(histories[6])

# %%
plot_hist(histories[7])

# %%
plot_hist(histories[8])

# %%
plot_hist(histories[9])

# %%
plot_hist(histories[10])

# %%
plot_hist(histories[11])

# %%
plot_hist(histories[12])

# %%
plot_hist(histories[13])

# %%
plot_hist(histories[14])

# %%
plot_hist(histories[15])

# %%
(train_images[splits[2][1]]).shape

# %%
(train_labels[splits[2][1]]).shape

# %%
model2_valdata = train_images[splits[2][1]], train_labels[splits[2][1]]

# %%
# evaluate model on test_dataset
models[2].evaluate(holdout_ds)
# Out:
# 9/9 [==============================] - 0s 9ms/step - loss: 10.1692 - sparse_categorical_accuracy: 0.4373
# [10.169238090515137, 0.4372623562812805]

# %%
# save model
#model.save('CTG_model_final')

# %%
# show confusion matrix
best_model = models[7]

predictions = np.array([])
labels =  np.array([])
for x, y in holdout_ds:
    predictions = np.concatenate([predictions, np.argmax(best_model.predict(x), axis=-1)])
    labels = np.concatenate([labels, (y.numpy())])



tf.math.confusion_matrix(labels=labels, predictions=predictions).numpy()
# Out:
# array([[18,  8,  1,  3, 22],
#        [ 9, 39,  1, 10, 38],
#        [ 1,  8,  1,  2, 10],
#        [ 1,  6,  0,  3,  1],
#        [ 8, 10,  2,  4, 57]], dtype=int32)

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

print(classification_report(labels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.35      0.40        52
#          1.0       0.55      0.40      0.46        97
#          2.0       0.20      0.05      0.07        22
#          3.0       0.14      0.27      0.18        11
#          4.0       0.45      0.70      0.55        81
#
#     accuracy                           0.45       263
#    macro avg       0.36      0.35      0.33       263
# weighted avg       0.46      0.45      0.43       263

# %%
# to make confusion matrix easier
y_true = labels.tolist()
y_pred = predictions.tolist()

# %%
disp = metrics.ConfusionMatrixDisplay.from_predictions(y_true, y_pred)
disp.figure_.suptitle("Confusion Matrix")
print(f"Confusion matrix:\n{disp.confusion_matrix}")

plt.show()
# Out:
# Confusion matrix:
# [[18  8  1  3 22]
#  [ 9 39  1 10 38]
#  [ 1  8  1  2 10]
#  [ 1  6  0  3  1]
#  [ 8 10  2  4 57]]
