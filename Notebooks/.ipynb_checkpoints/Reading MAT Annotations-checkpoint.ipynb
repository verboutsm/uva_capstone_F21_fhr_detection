# %%
# import scipy.io
import numpy as np
import pandas as pd
import os
import wfdb
from IPython.display import display
import matplotlib.pyplot as plt
import csv

# %%
mat = pd.read_csv('../data/annotations/csv/annotation_1001.csv', skip_blank_lines=False)
files = os.listdir('../data/annotations/csv/')

# %%
ann_list = []

with open('../data/annotations/csv/annotation_1001.csv', newline='') as csvfile:
    annreader = csv.reader(csvfile, delimiter=',')
    for i, row in enumerate(annreader):
        if 'UC' in ''.join(row):
            ann_list.append(i)
            
ann_sample = np.array(ann_list)

# %%
ann_sample
# Out:
# array([  425,   744,   966,  1136,  1457,  1641,  2470,  2791,  3293,
#         3554,  4220,  4515,  4919,  5219,  5519,  5879,  6119,  6359,
#         6479,  6719,  7019,  7319,  7439,  7619,  7799,  8039,  8159,
#         8879,  9239,  9359, 10079, 10319, 10799, 11159, 11399, 11519,
#        11759, 11999, 12239, 12479, 12839, 13019, 13319, 13559, 13799,
#        14039, 14279])

# %%
start = 0
end = 14400
# start = 400
# end = 1400
ann_filter = np.logical_and(np.greater_equal(ann_sample, start), np.less_equal(ann_sample, end))
ann_sample[ann_filter]

tmp = np.array([426, 742])

# %%
record = wfdb.rdrecord('../data/physionet_data/1001', sampfrom=start, sampto=end)
record.p_signal.shape
# Out:
# (14400, 2)

# %%
ann_sample
# Out:
# array([  425,   744,   966,  1136,  1457,  1641,  2470,  2791,  3293,
#         3554,  4220,  4515,  4919,  5219,  5519,  5879,  6119,  6359,
#         6479,  6719,  7019,  7319,  7439,  7619,  7799,  8039,  8159,
#         8879,  9239,  9359, 10079, 10319, 10799, 11159, 11399, 11519,
#        11759, 11999, 12239, 12479, 12839, 13019, 13319, 13559, 13799,
#        14039, 14279])

# %%
start = 425
end = 744

ann_filtered = ann_sample[ann_sample > start] #or ann_sample[ann_sample < end]
ann_filtered

ann_filtered

# %%
np.where((ann_sample > start) & (ann_sample < end))

# %%
mask = (ann_sample > start) | (ann_sample < end)
print(mask)

# %%
record.p_signal

# %%
df1001 = pd.read_csv('../data/database/signals/1001.csv')

# %%
pd.DataFrame(record.p_signal)
# Out:
#             0     1
# 0      150.50   7.0
# 1      150.50   8.5
# 2      151.00   8.5
# 3      151.25   7.5
# 4      151.25   9.5
# ...       ...   ...
# 14395  140.75  10.0
# 14396  141.00   9.5
# 14397  141.75   9.5
# 14398  141.75  10.0
# 14399  141.25  10.0
#
# [14400 rows x 2 columns]

# %%
plt.figure(figsize=(18,8))
plt.plot(df1001['seconds'][425:744], df1001['FHR'][425:744])

# %%
# wfdb.plot.plot_wfdb(record)
# ann = wfdb.rdann('../data/physionet_data/1001', 'hea', sampfrom=start, sampto=end)
record = wfdb.rdrecord('../data/physionet_data/1001', sampfrom=425, sampto=744)
wfdb.plot_items(signal=record.p_signal, fs=4,
                    ann_samp=[],
                    figsize=(18,8))

# %%
plt.plot(df1001['seconds'][425:744], df1001['UC'][425:744])

# %%
ann_sample[ann_sample < end]

# %%
ann1001.iloc[ann_list, :]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ch/d9scct7n1y30kqjyb9_tp4jc0000gn/T/ipykernel_23865/2332141514.py in <module>
# ----> 1 ann1001.iloc[ann_list, :]
#
# NameError: name 'ann1001' is not defined

# %%
ann1001 = pd.DataFrame(ann_list)
ann1001.rename(
    {
        0: 'tachy',
        1: 'brady',
        2: 'accel',
        3: 'decel',
        4: 'uc'
    }, axis = 1, inplace = True
)
ann1001.head(5)

# %%
with open('../data/annotations/csv/annotation_1001.csv') as file_name:
    file_read = csv.reader(file_name)
    array = list(file_read)

# %%
import pandas as pd

nrow, ncol = brady.shape

brady = brady.reshape(1, nrow*ncol)

# %%
brady_df = pd.DataFrame(brady.T)

# %%
brady_df.loc[0,0].dtype.name

# %%
brady_df[0] = brady_df[0].map(lambda x: 0 if x.dtype.name == "float64" else x)

# %%
set(brady_df)
